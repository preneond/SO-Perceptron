# %% [markdown]
# ## Structured Output Perceptron
#
# Ondrej Prenek
# 10.1.2019

# %% [markdown]
# ## Assignment 1

# %% [markdown]
# Necessary outputs

# %%
import numpy as np
import scipy.io as sio

# %% [markdown]
# ### Loading data

# %%
def load_data():
    mat = sio.loadmat('ocr_names.mat')
    trn_data = mat.get('TrnData')
    tst_data = mat.get('TstData')

    trn_size = trn_data.shape[1]
    trn_x = list()
    trn_y = list()
    for i in range(trn_size):
        trn_x.append(trn_data[0, i][1])
        trn_y.append(trn_data[0, i][2][0])

    tst_size = tst_data.shape[1]
    tst_x = list()
    tst_y = list()
    for i in range(tst_size):
        tst_x.append(tst_data[0, i][1])
        tst_y.append(tst_data[0, i][2][0])

    return trn_x, trn_y, tst_x, tst_y

# %%
trn_x, trn_y, tst_x, tst_y = load_data()

# %% [markdown]
# ### Perceptron class

# %%
class MultiClassPerceptron(object):
    def __init__(self, n_letters=26, n_features=8256):
        """
        Linear (dense, fully-connected) layer.
        :param n_letters
        :param n_dims:
        """
        self.n_letters = n_letters
        self.n_features = n_features
        self.W = np.zeros(shape=(self.n_letters, self.n_features))
        self.b = np.ones(shape=(self.n_letters, 1))

    def predict(self, x):
        z = np.dot(self.W, x) + self.b
        return np.argmax(z, axis=0)

    def train(self, X, Y, labels, threshold=500):
        """
        :param X: training samples (n_samples)
        :param y: (n_samples x letters)
        :param threshold:
        """

        all_correct = False
        for i in range(threshold):
            if all_correct:
                break

            print("Epoch: " + str(i))

            err_seqs = 0
            err_chars = 0
            all_correct = True
            for x, y in zip(X, Y):
                y_pred = self.predict(x)
                y_corr = list(map(lambda c: labels.index(c), y))

                if not np.array_equal(y_pred, y_corr):
                    all_correct = False
                    err_seqs += 1

                for j in range(len(y_pred)):
                    if not y_pred[j] == y_corr[j]:
                        err_chars += 1
                        c_correct = y_corr[j]
                        self.W[c_correct] += x[:, j]
                        self.b[c_correct] += 1

                        c_incorrect = y_pred[j]
                        self.W[c_incorrect] -= x[:, j]
                        self.b[c_incorrect] -= 1

            num_of_chars = sum(map(len, Y))

            print("Char Error: " + str(err_chars / num_of_chars))
            print("Seq Error: " + str(err_seqs / len(Y)))

    def test(self, X, Y, labels):
        err_words = 0
        err_chars = 0

        for x, y in zip(X, Y):
            y_pred = self.predict(x)
            y_corr = list(map(lambda c: labels.index(c), y))

            if not np.array_equal(y_pred, y_corr):
                err_words += 1
                err_chars += len(np.nonzero(np.subtract(y_pred, y_corr))[0])

        num_of_chars = sum(map(len, Y))
        char_err = err_chars / num_of_chars
        seq_err = err_words / len(Y)

        print("--------------------------------")
        print("TEST ERROR")
        print("Seq Error: " + str(seq_err))
        print("Char Error: " + str(char_err))

# %% [markdown]
# ### Perceptron Training

# %%
labels = sorted(''.join(set(''.join(trn_y))))
model = MultiClassPerceptron(n_letters=len(labels), n_features=trn_x[0].shape[0])
# Seq Error: 0.03
# Epoch: 39
# Char Error: 0.010800196367206676
# Seq Error: 0.043
# Epoch: 40
# Char Error: 0.009081983308787433
# Seq Error: 0.036
# Epoch: 41
# Char Error: 0.004663721158566519
# Seq Error: 0.019
# Epoch: 42
# Char Error: 0.006381934216985763
# Seq Error: 0.026
# Epoch: 43
# Char Error: 0.005891016200294551
# Seq Error: 0.024
# Epoch: 44
# Char Error: 0.007118311242022582
# Seq Error: 0.029
# Epoch: 45
# Char Error: 0.005400098183603338
# Seq Error: 0.022
# Epoch: 46
# Char Error: 0.0031909671084928816
# Seq Error: 0.013
# Epoch: 47
# Char Error: 0.0039273441335297005
# Seq Error: 0.016
# Epoch: 48
# Char Error: 0.004909180166912126
# Seq Error: 0.02
# Epoch: 49
# Char Error: 0.006381934216985763
# Seq Error: 0.026
# Epoch: 50
# Char Error: 0.004663721158566519
# Seq Error: 0.019
# Epoch: 51
# Char Error: 0.011536573392243496
# Seq Error: 0.044
# Epoch: 52
# Char Error: 0.006136475208640157
# Seq Error: 0.024
# Epoch: 53
# Char Error: 0.004172803141875307
# Seq Error: 0.017
# Epoch: 54
# Char Error: 0.005891016200294551
# Seq Error: 0.023
# Epoch: 55
# Char Error: 0.007363770250368188
# Seq Error: 0.03
# Epoch: 56
# Char Error: 0.002454590083456063
# Seq Error: 0.01
# Epoch: 57
# Char Error: 0.004418262150220913
# Seq Error: 0.018
# Epoch: 58
# Char Error: 0.008345606283750613
# Seq Error: 0.033
# Epoch: 59
# Char Error: 0.011782032400589101
# Seq Error: 0.047
# Epoch: 60
# Char Error: 0.006136475208640157
# Seq Error: 0.025
# Epoch: 61
# Char Error: 0.0066273932253313695
# Seq Error: 0.027
# Epoch: 62
# Char Error: 0.006872852233676976
# Seq Error: 0.028
# Epoch: 63
# Char Error: 0.008345606283750613
# Seq Error: 0.034
# Epoch: 64
# Char Error: 0.007609229258713795
# Seq Error: 0.029
# Epoch: 65
# Char Error: 0.0039273441335297005
# Seq Error: 0.016
# Epoch: 66
# Char Error: 0.00859106529209622
# Seq Error: 0.034
# Epoch: 67
# Char Error: 0.0066273932253313695
# Seq Error: 0.027
# Epoch: 68
# Char Error: 0.003681885125184094
# Seq Error: 0.015
# Epoch: 69
# Char Error: 0.0019636720667648502
# Seq Error: 0.008
# Epoch: 70
# Char Error: 0.0014727540500736377
# Seq Error: 0.006
# Epoch: 71
# Char Error: 0.0004909180166912126
# Seq Error: 0.002
# Epoch: 72
# Char Error: 0.0
# Seq Error: 0.0

# %% [markdown]
# ### Evaluating perceptron on test data

# %%
model.test(tst_x, tst_y, labels)
# Out:
# --------------------------------
# TEST ERROR
# Seq Error: 0.694
# Char Error: 0.2502360717658168

# %% [markdown]
# |                                    | $R^{seq}$ (%) | $R^{char}$ (%) |
# |------------------------------------|---------------|----------------|
# | independent multi-class classifier | 69.4          | 25.024         |
